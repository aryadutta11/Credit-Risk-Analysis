# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\Credit_risk_analysis\data\raw\credit_risk_dataset.csv")

# %%
#remove duplicate records
print("Original Shape:",df.shape)
df = df.drop_duplicates()
print("after removing duplicates",df.shape)
# Out:
# Original Shape: (32581, 12)
# after removing duplicates (32416, 12)

# %%
#missing values
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              887
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3095
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
#handling numeric values
numeric_columns = df.select_dtypes(include=["int64","Float64"]).columns

for col in numeric_columns:
    df[col]=df[col].fillna(df[col].median())

#handling categorical values
categorical_columns = df.select_dtypes(include=["object"]).columns

for col in categorical_columns:
    df[col]=df[col].fillna(df[col].mode()[0])

print("\nAfter removing Missing Values")
print(df.isnull().sum())
# Out:
# After removing Missing Values
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
#removing impossible ages
df = df[(df["person_age"] >= 18) &
        (df["person_age"] <= 100)]

# %%
#removing impossible income values
df = df[df["person_income"] > 0]

# %%
#removing impossible loan amounts
df = df[df["loan_amnt"] > 0]

# %%
#removing impossible interest rates
df = df[(df["loan_int_rate"] >= 0) &
        (df["loan_int_rate"] <= 100)]

# %%
#removing invalid target values
df = df[df["loan_status"].isin([0,1])]

# %%
print("\nFinal shape:", df.shape)

print("\nRemaining missing values:")
print(df.isnull().sum())

print("\nTarget distribution:")
print(df["loan_status"].value_counts())

print("\nTarget percentage:")
print(df["loan_status"].value_counts(normalize=True) * 100)
# Out:
# Final shape: (32411, 12)
#
# Remaining missing values:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64
#
# Target distribution:
# loan_status
# 0    25322
# 1     7089
# Name: count, dtype: int64
#
# Target percentage:
# loan_status
# 0    78.127796
# 1    21.872204
# Name: proportion, dtype: float64

# %%
df.to_csv(
    r"C:\Users\User\Desktop\Credit_risk_analysis\data\processed\credit_risk_dataset.csv",
    index=False
)

print("\nClean dataset saved.")
# Out:
# Clean dataset saved.
